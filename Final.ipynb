# %%
import strawberryfields as sf
import numpy as np
import matplotlib.pyplot as plt
from typing import List, Tuple, Dict
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from scipy.stats import skew, kurtosis
from itertools import product
import multiprocessing as mp
import json
import os
import seaborn as sns
from tqdm import tqdm   # <-- Added import for progress bar

# ==============================================================================
# CONFIGURATION: ALL PARAMETERS USED IN THE PIPELINE
# ==============================================================================
PIPELINE_CONFIG = {
    "sf_hbar": 1,
    "quad_range": (-6, 6),
    "quad_points": 200, 
    "num_run_per_sample": 5,    
    "num_shots": 500,    # homodyne measurements per grid point (not used for these marginal features)
    "grid": {
        # "num_db": 3,       # distinct squeezing values (in dB)
        "num_loss": 3,     # distinct loss values
        "num_gamma": 3     # distinct dephasing values
    },
    # "db_range": (10.0, 13.0),   # dB values range
    "loss_range": (0.9, 1.0),     # this actually transimitivity
    "gamma_range": (0.0, 0.2),    # dephasing values range
    "model": {
        "input_shape": (8,),        
        "loss_bins": 20,
        "dephasing_bins": 20,
        "learning_rate": 1e-3,
        "epochs": 1000,
        "batch_size": 32,
        "validation_split": 0
    },
    "save_paths": {
        "dataset": "dataset.npz",
        "model": "trained_model.h5",
        "config": "pipeline_config.json"
    }
}

# Save the pipeline configuration to disk.
with open(PIPELINE_CONFIG["save_paths"]["config"], "w") as f:
    json.dump(PIPELINE_CONFIG, f, indent=4)

# ==============================================================================
# SETUP: CONFIGURATION PARAMETERS AND GLOBAL VARIABLES
# ==============================================================================
print("Step 1: Setting configuration parameters.")
CONFIG = {
    "hbar": PIPELINE_CONFIG["sf_hbar"],
    "quad_range": PIPELINE_CONFIG["quad_range"],
    "quad_points": PIPELINE_CONFIG["quad_points"],
    "cmap": plt.cm.RdBu,
    "colors": {
        "q_marginal": "navy",
        "p_marginal": "maroon",
        "samples_x": "skyblue",
        "samples_p": "lightcoral",
        "ideal": "red",
        "noisy": "green"
    }
}
sf.hbar = CONFIG["hbar"]
CONFIG["scale"] = np.sqrt(CONFIG["hbar"] * np.pi)
print("Configuration set. Scale =", CONFIG["scale"])

# ==============================================================================
# UTILITY: dB to epsilon conversion and feature extraction
# ==============================================================================
def db_to_epsilon(db_val: float) -> float:
    """
    Convert a given GKP squeezing level in dB to epsilon via:
         tanh(epsilon) = 10^(-db_val/10)
    """
    t = 10.0 ** (-db_val / 10.0)
    eps = 0.5 * np.log((1.0 + t) / (1.0 - t))
    return eps

def extract_statistical_features(samples_x: np.ndarray, samples_p: np.ndarray) -> np.ndarray:
    """Extract mean, variance, skewness, and kurtosis for X and P quadratures."""
    x_features = [
        np.mean(samples_x), np.var(samples_x),
        skew(samples_x), kurtosis(samples_x)
    ]
    p_features = [
        np.mean(samples_p), np.var(samples_p),
        skew(samples_p), kurtosis(samples_p)
    ]
    return np.array(x_features + p_features)

def extract_histogram_features(
    samples_x: np.ndarray, 
    samples_p: np.ndarray, 
    bins: int = 100, 
    range_val: Tuple[float, float] = (-6, 6)
) -> np.ndarray:
    """
    Compute histograms for X and P quadrature samples and return a concatenated feature vector.
    The histograms are computed with density=True so that they approximate a probability density.
    """
    hist_x, _ = np.histogram(samples_x, bins=bins, density=True, range=range_val)
    hist_p, _ = np.histogram(samples_p, bins=bins, density=True, range=range_val)
    return np.concatenate([hist_x, hist_p])
# Out:
# Step 1: Setting configuration parameters.
# Configuration set. Scale = 1.7724538509055159

# %%
# ==============================================================================
# CORE SIMULATION FUNCTIONS
# ==============================================================================

def simulate_homodyne(prep_state: List[float], epsilon: float, noise_params: Dict, num_samples: int) -> Tuple[np.ndarray, np.ndarray]:
    """
    Simulate homodyne measurements (X and P quadratures) for a given epsilon and noise parameters.
    Returns two arrays of measurement outcomes.
    """
    samples_x, samples_p = [], []
    for _ in range(num_samples):
        prog_x = sf.Program(1)
        with prog_x.context as q:
            sf.ops.GKP(state=prep_state, epsilon=epsilon) | q
            if 'loss' in noise_params:
                sf.ops.LossChannel(noise_params['loss']) | q
            if 'gamma' in noise_params:
                theta = np.random.normal(0, np.sqrt(2 * noise_params['gamma']))
                sf.ops.Rgate(theta) | q
            sf.ops.MeasureX | q
        eng_x = sf.Engine("bosonic")
        sample_x = eng_x.run(prog_x).samples[0, 0] / CONFIG["scale"]
        samples_x.append(sample_x)
        
        prog_p = sf.Program(1)
        with prog_p.context as q:
            sf.ops.GKP(state=prep_state, epsilon=epsilon) | q
            if 'loss' in noise_params:
                sf.ops.LossChannel(noise_params['loss']) | q
            if 'gamma' in noise_params:
                theta = np.random.normal(0, np.sqrt(2 * noise_params['gamma']))
                sf.ops.Rgate(theta) | q
            sf.ops.MeasureP | q
        eng_p = sf.Engine("bosonic")
        sample_p = eng_p.run(prog_p).samples[0, 0] / CONFIG["scale"]
        samples_p.append(sample_p)
    
    return np.array(samples_x), np.array(samples_p)

def plot_quadratures(
    samples_x: np.ndarray,
    samples_p: np.ndarray,
    noisy_x: np.ndarray,
    noisy_p: np.ndarray,
    title: str = "",
    figsize: Tuple[float, float] = (12, 5)
):
    """Plot quadrature measurement results"""
    quad_axis = np.linspace(-6, 6, 1000)
    fig, axs = plt.subplots(1, 2, figsize=figsize)
    
    # X quadrature
    x_hist, x_bin_edges, _ = axs[0].hist(samples_x, bins=100, density=True, 
               color=CONFIG["colors"]["samples_x"], label="Samples")
    # axs[0].plot(quad_axis, ideal_x, '--', color=CONFIG["colors"]["ideal"], label="Ideal")
    axs[0].plot(quad_axis, noisy_x, '-', color=CONFIG["colors"]["noisy"], label="Noisy")
    axs[0].set_xlabel(r"$q$ ($\sqrt{\pi\hbar}$)", fontsize=12)
    axs[0].set_ylabel("Probability Density", fontsize=12)

    # Add bin overlays for X quadrature
    for j in range(-3, 4):
        axs[0].axvspan(2*j - 0.5, 2*j + 0.5, alpha=0.2, facecolor='b')
        axs[0].axvspan(2*j + 0.5, 2*j + 1.5, alpha=0.2, facecolor='r')
    
    # P quadrature
    p_hist, p_bin_edges, _ = axs[1].hist(samples_p, bins=100, density=True, 
               color=CONFIG["colors"]["samples_p"], label="Samples")
    # axs[1].plot(quad_axis, ideal_p, '--', color=CONFIG["colors"]["ideal"], label="Ideal")
    axs[1].plot(quad_axis, noisy_p, '-', color=CONFIG["colors"]["noisy"], label="Noisy")
    axs[1].set_xlabel(r"$p$ ($\sqrt{\pi\hbar}$)", fontsize=12)

    # Add bin overlays for P quadrature
    for j in range(-3, 4):
        axs[1].axvspan(2*j - 0.5, 2*j + 0.5, alpha=0.2, facecolor='b')
        axs[1].axvspan(2*j + 0.5, 2*j + 1.5, alpha=0.2, facecolor='r')
    
    for ax in axs:
        ax.legend()
        ax.tick_params(axis='both', which='major', labelsize=10)
    
    if title:
        fig.suptitle(title, y=1.02)
    plt.tight_layout()
    plt.show()

    return (x_hist, x_bin_edges), (p_hist, p_bin_edges)

# %%
print("Step 3: Preparing grid parameters for dataset generation.")

grid_config = PIPELINE_CONFIG["grid"]
num_loss = grid_config["num_loss"]
num_gamma = grid_config["num_gamma"]

# Define the parameter ranges.
loss_values = np.linspace(PIPELINE_CONFIG["loss_range"][0], PIPELINE_CONFIG["loss_range"][1], num_loss)
gamma_values = np.linspace(PIPELINE_CONFIG["gamma_range"][0], PIPELINE_CONFIG["gamma_range"][1], num_gamma)

print(loss_values)
print(gamma_values)

# Define the GKP preparation states and dB values.
prop_states = [[0, 0]]
db = [10.0]

# Create a grid over all parameters: (prep_state, db, loss, gamma)
grid_params = list(product(prop_states, db, loss_values, gamma_values))

def process_grid_point(params):
    prep_state, db_val, loss_val, gamma_val = params
    epsilon = db_to_epsilon(db_val)
    current_noise_params = {"loss": loss_val, "gamma": gamma_val}

    # Run the simulation multiple times for this grid point.
    features_all = []
    for _ in range(PIPELINE_CONFIG["num_run_per_sample"]):
        samples_x, samples_p = simulate_homodyne(
            prep_state=prep_state,
            epsilon=epsilon,
            noise_params=current_noise_params,
            num_samples=PIPELINE_CONFIG["num_shots"]
        )
       
        features = extract_histogram_features(samples_x, samples_p, bins=100, range_val=(-6, 6))
        features_all.append(features)
    
    # Map the (loss, gamma) to discrete indices for classification.
    loss_idx = np.where(np.isclose(loss_values, loss_val))[0][0]
    dephasing_idx = np.where(np.isclose(gamma_values, gamma_val))[0][0]
    return features_all, loss_idx, dephasing_idx

dataset_path = PIPELINE_CONFIG["save_paths"]["dataset"]
if not os.path.exists(dataset_path):
    print("No dataset found. Generating new dataset...")
    results = []
    for params in tqdm(grid_params, total=len(grid_params)):
        results.append(process_grid_point(params))

    X_data_list = []
    y_joint_list = []
    for features_list, loss_idx, dephasing_idx in results:
        joint_label = loss_idx * num_gamma + dephasing_idx
        for features in features_list:
            X_data_list.append(features)
            y_joint_list.append(joint_label)
    
    X_data = np.array(X_data_list)
    y_joint = np.array(y_joint_list)
   
    # Save the dataset.
    np.savez_compressed(PIPELINE_CONFIG["save_paths"]["dataset"],
                        X_data=X_data, y_joint=y_joint)
    print("Dataset saved to", PIPELINE_CONFIG["save_paths"]["dataset"])
else:
    data = np.load(PIPELINE_CONFIG["save_paths"]["dataset"], allow_pickle=True)
    X_data = data['X_data']
    y_joint = data['y_joint']
#         1.67763073,  0.00531213, -0.09200261])], np.int64(2), np.int64(1))
#  89%|████████▉ | 8/9 [07:03<00:50, 50.26s/it]
# ([array([-0.01261742,  1.56451222, -0.19731502,  0.38871428, -0.00317696,
#         1.57999166,  0.05260194, -0.00401636]), array([ 0.04869261,  1.43970147, -0.0298189 ,  0.63513116,  0.05478278,
#         1.5155953 ,  0.0215234 , -0.10493884]), array([ 0.0384457 ,  1.52174794, -0.04088092,  0.0450055 , -0.05620055,
#         1.69934165, -0.01771916, -0.32608565]), array([-0.01297731,  1.3966071 , -0.02441625, -0.0434327 , -0.13806146,
#         1.5954312 ,  0.15355227,  0.11424494]), array([-0.08435546,  1.7487134 , -0.05411384,  0.12771075,  0.01291343,
#         1.45984982,  0.04712796,  0.05842642])], np.int64(2), np.int64(2))
# 100%|██████████| 9/9 [07:52<00:00, 52.49s/it]
# Dataset saved to dataset.npz

# %%
def build_joint_fnn_model(input_shape: Tuple[int], num_loss: int, num_gamma: int) -> Model:
    num_classes = num_loss * num_gamma
    inputs = Input(shape=input_shape, name='features')
    
    # Larger or additional Dense layers
    x = Dense(512, activation='relu')(inputs)
    x = Dropout(0.3)(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.3)(x)
    
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.3)(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.3)(x)
    
    # Possibly another layer if you want
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.3)(x)
    
    # Final output for 400 bins
    joint_output = Dense(num_classes, activation='softmax', name='joint_output')(x)
    model = Model(inputs=inputs, outputs=joint_output)
    return model

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

model_config = PIPELINE_CONFIG["model"]
input_shape = model_config["input_shape"]

model = build_joint_fnn_model(input_shape, num_loss, num_gamma)
model.compile(
    optimizer=Adam(learning_rate=model_config["learning_rate"]),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
print("Starting model training...")

# Option 1: No validation split
history = model.fit(
    X_data, y_joint,
    epochs=model_config["epochs"],
    batch_size=model_config["batch_size"],
    validation_split=0,
    callbacks=[ReduceLROnPlateau(monitor='loss', factor=0.5, patience=5, verbose=1, min_lr=1e-6)],
    verbose=1
)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ features (InputLayer)           │ (None, 8)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │         4,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ joint_output (Dense)            │ (None, 9)              │         1,161 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 449,161 (1.71 MB)
#  Trainable params: 449,161 (1.71 MB)
#  Non-trainable params: 0 (0.00 B)
# Starting model training...
# Epoch 1/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.1810 - loss: 2.2053 - learning_rate: 0.0010
# Epoch 2/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0549 - loss: 2.2148 - learning_rate: 0.0010
# Epoch 3/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.2062 - loss: 2.2021 - learning_rate: 0.0010
# Epoch 4/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1662 - loss: 2.1851 - learning_rate: 0.0010
# Epoch 5/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0757 - loss: 2.1776 - learning_rate: 0.0010
# Epoch 6/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.1157 - loss: 2.1785 - learning_rate: 0.0010
# Epoch 7/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1157 - loss: 2.2055 - learning_rate: 0.0010
# Epoch 8/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1053 - loss: 2.2230 - learning_rate: 0.0010
# Epoch 9/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0801 - loss: 2.2023 - learning_rate: 0.0010
# Epoch 10/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2271 - loss: 2.1625 - learning_rate: 0.0010
# Epoch 11/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.1410 - loss: 2.1726 - learning_rate: 0.0010
# Epoch 12/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.1958 - loss: 2.1694 - learning_rate: 0.0010
# Epoch 13/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0549 - loss: 2.2113 - learning_rate: 0.0010
# Epoch 14/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0505 - loss: 2.2529 - learning_rate: 0.0010
# Epoch 15/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.0938 - loss: 2.2035
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1053 - loss: 2.2005 - learning_rate: 0.0010
# Epoch 16/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.0549 - loss: 2.2137 - learning_rate: 5.0000e-04
# Epoch 17/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1558 - loss: 2.1948 - learning_rate: 5.0000e-04
# Epoch 18/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0905 - loss: 2.2033 - learning_rate: 5.0000e-04
# Epoch 19/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.
# Epoch 164/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1410 - loss: 2.2236 - learning_rate: 1.0000e-06
# Epoch 165/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.1097 - loss: 2.1674 - learning_rate: 1.0000e-06
# Epoch 166/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1009 - loss: 2.2000 - learning_rate: 1.0000e-06
# Epoch 167/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1558 - loss: 2.1779 - learning_rate: 1.0000e-06
# Epoch 168/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1558 - loss: 2.1802 - learning_rate: 1.0000e-06
# Epoch 169/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1053 - loss: 2.2046 - learning_rate: 1.0000e-06
# Epoch 170/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1662 - loss: 2.1610 - learning_rate: 1.0000e-06
# Epoch 171/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1306 - loss: 2.1880 - learning_rate: 1.0000e-06
# Epoch 172/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0505 - loss: 2.2099 - learning_rate: 1.0000e-06
# Epoch 173/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1810 - loss: 2.1874 - learning_rate: 1.0000e-06
# Epoch 174/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1009 - loss: 2.1846 - learning_rate: 1.0000e-06
# Epoch 175/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1262 - loss: 2.1871 - learning_rate: 1.0000e-06
# Epoch 176/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1053 - loss: 2.2026 - learning_rate: 1.0000e-06
# Epoch 177/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0905 - loss: 2.2062 - learning_rate: 1.0000e-06
# Epoch 178/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0549 - loss: 2.2239 - learning_rate: 1.0000e-06
# Epoch 179/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0905 - loss: 2.1717 - learning_rate: 1.0000e-06
# Epoch 180/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0653 - loss: 2.1898 - learning_rate: 1.0000e-06
# Epoch 181/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1602 - loss: 2.1751 - learning_rate: 1.0000e-06
# Epoch 182/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1306 - loss: 2.1907 - learning_rate: 1.0000e-06
# Epoch 183/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.1157 - loss: 2.2109 - learning_rate: 1.0000e-06
# Epoch 184/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0949 - loss: 2.2369 - learning_rate: 1.0000e-06
# Epoch 185/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1009 - loss: 2.1980 - learning_rate: 1.0000e-06
# Epoch 186/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.1009 - loss: 2.1841 - learning_rate: 1.0000e-06
# Epoch 187/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1558 - loss: 2.2036 - learning_rate: 1.0000e-06
# Epoch 188/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.1201 - loss: 2.1877 - learning_rate: 1.0000e-06
# Epoch 189/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0757 - loss: 2.2012 - learning_rate: 1.0000e-06
# Epoch 190/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0905 - loss: 2.1965 - learning_rate: 1.0000e-06
# Epoch 191/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0653 - loss: 2.1831 - learning_rate: 1.0000e-06
# Epoch 192/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1306 - loss: 2.1717 - learning_rate: 1.0000e-06
# Epoch 193/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.1558 - loss: 2.1840 - learning_rate: 1.0000e-06
# Epoch 194/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.1914 - loss: 2.1706 - learning_rate: 1.0000e-06
# Epoch 195/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2315 - loss: 2.1718 - learning_rate: 1.0000e-06
# Epoch 196/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.1157 - loss: 2.1865 - learning_rate: 1.0000e-06
# Epoch 197/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.1009 - loss: 2.2010 - learning_rate: 1.0000e-06
# Epoch 198/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.1662 - loss: 2.1840 - learning_rate: 1.0000e-06
# Epoch 199/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.1157 - loss: 2.2030 - learning_rate: 1.0000e-06
# Epoch 200/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.1558 - loss: 2.1843 - learning_rate: 1.0000e-06
# Epoch 201/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.1157 - loss: 2.2170 - learning_rate: 1.0000e-06
# Epoch 202/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.1410 - loss: 2.1779 - learning_rate: 1.0000e-06
# Epoch 203/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.1306 - loss: 2.1827 - learning_rate: 1.0000e-06
# Epoch 204/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.1410 - loss: 2.1797 - learning_rate: 1.0000e-06
# Epoch 205/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.1410 - loss: 2.1928 - learning_rate: 1.0000e-06
# Epoch 206/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.1810 - loss: 2.1401 - learning_rate: 1.0000e-06
# Epoch 207/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.1053 - loss: 2.1767 - learning_rate: 1.0000e-06
# Epoch 208/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.0801 - loss: 2.2087 - learning_rate: 1.0000e-06
# Epoch 209/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.0757 - loss: 2.1970 - learning_rate: 1.0000e-06
# Epoch 210/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.0653 - loss: 2.1923 - learning_rate: 1.0000e-06
# Epoch 211/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0653 - loss: 2.1691 - learning_rate: 1.0000e-06
# Epoch 212/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1157 - loss: 2.1948 - learning_rate: 1.0000e-06
# Epoch 213/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.1706 - loss: 2.1868 - learning_rate: 1.0000e-06
# Epoch 214/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1306 - loss: 2.1831 - learning_rate: 1.0000e-06
# Epoch 215/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0949 - loss: 2.1893 - learning_rate: 1.0000e-06
# Epoch 216/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1706 - loss: 2.1952 - learning_rate: 1.0000e-06
# Epoch 217/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1706 - loss: 2.1777 - learning_rate: 1.0000e-06
# Epoch 218/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1958 - loss: 2.1856 - learning_rate: 1.0000e-06
# Epoch 219/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1157 - loss: 2.1900 - learning_rate: 1.0000e-06
# Epoch 220/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1306 - loss: 2.2063 - learning_rate: 1.0000e-06
# Epoch 221/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.1514 - loss: 2.1746 - learning_rate: 1.0000e-06
# Epoch 222/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1410 - loss: 2.2183 - learning_rate: 1.0000e-06
# Epoch 223/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0801 - loss: 2.2145 - learning_rate: 1.0000e-06
# Epoch 224/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0697 - loss: 2.2106 - learning_rate: 1.0000e-06
# Epoch 225/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0949 - loss: 2.2033 - learning_rate: 1.0000e-06
# Epoch 226/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1514 - loss: 2.1868 - learning_rate: 1.0000e-06
# Epoch 227/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2463 - loss: 2.1709 - learning_rate: 1.0000e-06
# Epoch 228/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0905 - loss: 2.2048 - learning_rate: 1.0000e-06
# Epoch 229/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0653 - loss: 2.2186 - learning_rate: 1.0000e-06
# Epoch 230/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.1350 - loss: 2.1895 - learning_rate: 1.0000e-06
# Epoch 231/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.1157 - loss: 2.1916 - learning_rate: 1.0000e-06
# Epoch 232/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0905 - loss: 2.2079 - learning_rate: 1.0000e-06
# Epoch 233/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1410 - loss: 2.1917 - learning_rate: 1.0000e-06
# Epoch 234/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1706 - loss: 2.1776 - learning_rate: 1.0000e-06
# Epoch 235/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1157 - loss: 2.2132 - learning_rate: 1.0000e-06
# Epoch 236/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1454 - loss: 2.1802 - learning_rate: 1.0000e-06
# Epoch 237/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0905 - loss: 2.2010 - learning_rate: 1.0000e-06
# Epoch 238/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1306 - loss: 2.1953 - learning_rate: 1.0000e-06
# Epoch 239/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1009 - loss: 2.1716 - learning_rate: 1.0000e-06
# Epoch 240/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1854 - loss: 2.1875 - learning_rate: 1.0000e-06
# Epoch 241/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0653 - loss: 2.2065 - learning_rate: 1.0000e-06
# Epoch 242/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2819 - loss: 2.1582 - learning_rate: 1.0000e-06
# Epoch 243/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1958 - loss: 2.1795 - learning_rate: 1.0000e-06
# Epoch 244/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1662 - loss: 2.1757 - learning_rate: 1.0000e-06
# Epoch 245/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0400 - loss: 2.2099 - learning_rate: 1.0000e-06
# Epoch 246/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1914 - loss: 2.1687 - learning_rate: 1.0000e-06
# Epoch 247/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1454 - loss: 2.2034 - learning_rate: 1.0000e-06
# Epoch 248/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2211 - loss: 2.1943 - learning_rate: 1.0000e-06
# Epoch 249/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1306 - loss: 2.1970 - learning_rate: 1.0000e-06
# Epoch 250/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0653 - loss: 2.2150 - learning_rate: 1.0000e-06
# Epoch 251/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.1602 - loss: 2.1910 - learning_rate: 1.0000e-06
# Epoch 252/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0905 - loss: 2.1981 - learning_rate: 1.0000e-06
# Epoch 253/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0905 - loss: 2.2051 - learning_rate: 1.0000e-06
# Epoch 254/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.2106 - loss: 2.1412 - learning_rate: 1.0000e-06
# Epoch 255/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0697 - loss: 2.1846 - learning_rate: 1.0000e-06
# Epoch 256/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1157 - loss: 2.1969 - learning_rate: 1.0000e-06
# Epoch 257/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0905 - loss: 2.2035 - learning_rate: 1.0000e-06
# Epoch 258/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2062 - loss: 2.1588 - learning_rate: 1.0000e-06
# Epoch 259/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1410 - loss: 2.1736 - learning_rate: 1.0000e-06
# Epoch 260/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1706 - loss: 2.2002 - learning_rate: 1.0000e-06
# Epoch 261/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0905 - loss: 2.1786 - learning_rate: 1.0000e-06
# Epoch 262/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1306 - loss: 2.1673 - learning_rate: 1.0000e-06
# Epoch 263/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1410 - loss: 2.2015 - learning_rate: 1.0000e-06
# Epoch 264/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0905 - loss: 2.1861 - learning_rate: 1.0000e-06
# Epoch 265/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1410 - loss: 2.1818 - learning_rate: 1.0000e-06
# Epoch 266/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1009 - loss: 2.2001 - learning_rate: 1.0000e-06
# Epoch 267/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1662 - loss: 2.1896 - learning_rate: 1.0000e-06
# Epoch 268/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.2167 - loss: 2.1863 - learning_rate: 1.0000e-06
# Epoch 269/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.1662 - loss: 2.1985 - learning_rate: 1.0000e-06
# Epoch 270/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1558 - loss: 2.2229 - learning_rate: 1.0000e-06
# Epoch 271/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1410 - loss: 2.1814 - learning_rate: 1.0000e-06
# Epoch 272/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1810 - loss: 2.2039 - learning_rate: 1.0000e-06
# Epoch 273/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.2062 - loss: 2.1658 - learning_rate: 1.0000e-06
# Epoch 274/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.1766 - loss: 2.1715 - learning_rate: 1.0000e-06
# Epoch 275/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.0905 - loss: 2.1816 - learning_rate: 1.0000e-06
# Epoch 276/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0905 - loss: 2.1760 - learning_rate: 1.0000e-06
# Epoch 277/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.1410 - loss: 2.2165 - learning_rate: 1.0000e-06
# Epoch 278/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1706 - loss: 2.1669 - learning_rate: 1.0000e-06
# Epoch 279/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.2419 - loss: 2.1772 - learning_rate: 1.0000e-06
# Epoch 280/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0549 - loss: 2.1996 - learning_rate: 1.0000e-06
# Epoch 281/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.1009 - loss: 2.2330 - learning_rate: 1.0000e-06
# Epoch 282/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.1262 - loss: 2.1784 - learning_rate: 1.0000e-06
# Epoch 283/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.0905 - loss: 2.2099 - learning_rate: 1.0000e-06
# Epoch 284/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1454 - loss: 2.1527 - learning_rate: 1.0000e-06
# Epoch 285/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1706 - loss: 2.1899 - learning_rate: 1.0000e-06
# Epoch 286/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0949 - loss: 2.1915 - learning_rate: 1.0000e-06
# Epoch 287/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.2211 - loss: 2.1887 - learning_rate: 1.0000e-06
# Epoch 288/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1053 - loss: 2.2003 - learning_rate: 1.0000e-06
# Epoch 289/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1558 - loss: 2.1958 - learning_rate: 1.0000e-06
# Epoch 290/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1558 - loss: 2.1816 - learning_rate: 1.0000e-06
# Epoch 291/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1009 - loss: 2.1909 - learning_rate: 1.0000e-06
# Epoch 292/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.0905 - loss: 2.2016 - learning_rate: 1.0000e-06
# Epoch 293/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.1410 - loss: 2.1791 - learning_rate: 1.0000e-06
# Epoch 294/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.2062 - loss: 2.1873 - learning_rate: 1.0000e-06
# Epoch 295/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.1706 - loss: 2.1887 - learning_rate: 1.0000e-06
# Epoch 296/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.1410 - loss: 2.1960 - learning_rate: 1.0000e-06
# Epoch 297/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.1558 - loss: 2.1881 - learning_rate: 1.0000e-06
# Epoch 298/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.0505 - loss: 2.1962 - learning_rate: 1.0000e-06
# Epoch 299/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.0549 - loss: 2.2114 - learning_rate: 1.0000e-06
# Epoch 300/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.2062 - loss: 2.1754 - learning_rate: 1.0000e-06
# Epoch 301/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.0801 - loss: 2.2019 - learning_rate: 1.0000e-06
# Epoch 302/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.0905 - loss: 2.2045 - learning_rate: 1.0000e-06
# Epoch 303/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.1602 - loss: 2.1796 - learning_rate: 1.0000e-06
# Epoch 304/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.1410 - loss: 2.2050 - learning_rate: 1.0000e-06
# Epoch 305/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.2062 - loss: 2.1885 - learning_rate: 1.0000e-06
# Epoch 306/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.1514 - loss: 2.1751 - learning_rate: 1.0000e-06
# Epoch 307/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.1558 - loss: 2.1739 - learning_rate: 1.0000e-06
# Epoch 308/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.2106 - loss: 2.1880 - learning_rate: 1.0000e-06
# Epoch 309/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1410 - loss: 2.2289 - learning_rate: 1.0000e-06
# Epoch 310/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0697 - loss: 2.2074 - learning_rate: 1.0000e-06
# Epoch 311/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0949 - loss: 2.1942 - learning_rate: 1.0000e-06
# Epoch 312/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1053 - loss: 2.1907 - learning_rate: 1.0000e-06
# Epoch 313/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2019 - loss: 2.1977 - learning_rate: 1.0000e-06
# Epoch 314/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1410 - loss: 2.2036 - learning_rate: 1.0000e-06
# Epoch 315/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1958 - loss: 2.1747 - learning_rate: 1.0000e-06
# Epoch 316/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2715 - loss: 2.1543 - learning_rate: 1.0000e-06
# Epoch 317/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1053 - loss: 2.2093 - learning_rate: 1.0000e-06
# Epoch 318/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1009 - loss: 2.2085 - learning_rate: 1.0000e-06
# Epoch 319/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1514 - loss: 2.1853 - learning_rate: 1.0000e-06
# Epoch 320/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1558 - loss: 2.1802 - learning_rate: 1.0000e-06
# Epoch 321/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1706 - loss: 2.2227 - learning_rate: 1.0000e-06
# Epoch 322/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.1958 - loss: 2.1673 - learning_rate: 1.0000e-06
# Epoch 323/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2359 - loss: 2.1713 - learning_rate: 1.0000e-06
# Epoch 324/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0905 - loss: 2.2037 - learning_rate: 1.0000e-06
# Epoch 325/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.1602 - loss: 2.1766 - learning_rate: 1.0000e-06
# Epoch 326/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1201 - loss: 2.1663 - learning_rate: 1.0000e-06
# Epoch 327/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1053 - loss: 2.2019 - learning_rate: 1.0000e-06
# Epoch 328/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1009 - loss: 2.2188 - learning_rate: 1.0000e-06
# Epoch 329/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2211 - loss: 2.1973 - learning_rate: 1.0000e-06
# Epoch 330/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1157 - loss: 2.2023 - learning_rate: 1.0000e-06
# Epoch 331/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1157 - loss: 2.1727 - learning_rate: 1.0000e-06
# Epoch 332/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1157 - loss: 2.2084 - learning_rate: 1.0000e-06
# Epoch 333/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1306 - loss: 2.2092 - learning_rate: 1.0000e-06
# Epoch 334/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1053 - loss: 2.1592 - learning_rate: 1.0000e-06
# Epoch 335/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2167 - loss: 2.1681 - learning_rate: 1.0000e-06
# Epoch 336/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1958 - loss: 2.1349 - learning_rate: 1.0000e-06
# Epoch 337/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.2062 - loss: 2.1640 - learning_rate: 1.0000e-06
# Epoch 338/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1662 - loss: 2.1917 - learning_rate: 1.0000e-06
# Epoch 339/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0801 - loss: 2.2072 - learning_rate: 1.0000e-06
# Epoch 340/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1558 - loss: 2.1914 - learning_rate: 1.0000e-06
# Epoch 341/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1306 - loss: 2.1525 - learning_rate: 1.0000e-06
# Epoch 342/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1053 - loss: 2.2025 - learning_rate: 1.0000e-06
# Epoch 343/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1958 - loss: 2.1802 - learning_rate: 1.0000e-06
# Epoch 344/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1706 - loss: 2.1820 - learning_rate: 1.0000e-06
# Epoch 345/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1558 - loss: 2.1589 - learning_rate: 1.0000e-06
# Epoch 346/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1262 - loss: 2.1915 - learning_rate: 1.0000e-06
# Epoch 347/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1410 - loss: 2.1866 - learning_rate: 1.0000e-06
# Epoch 348/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1810 - loss: 2.1850 - learning_rate: 1.0000e-06
# Epoch 349/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.1558 - loss: 2.1827 - learning_rate: 1.0000e-06
# Epoch 350/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1766 - loss: 2.1893 - learning_rate: 1.0000e-06
# Epoch 351/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0949 - loss: 2.1886 - learning_rate: 1.0000e-06
# Epoch 352/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1646 - loss: 2.1853 - learning_rate: 1.0000e-06
# Epoch 353/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0252 - loss: 2.1745 - learning_rate: 1.0000e-06
# Epoch 354/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0653 - loss: 2.1869 - learning_rate: 1.0000e-06
# Epoch 355/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0905 - loss: 2.1999 - learning_rate: 1.0000e-06
# Epoch 356/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0757 - loss: 2.2006 - learning_rate: 1.0000e-06
# Epoch 357/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.1410 - loss: 2.1778 - learning_rate: 1.0000e-06
# Epoch 358/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1914 - loss: 2.2037 - learning_rate: 1.0000e-06
# Epoch 359/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1914 - loss: 2.1730 - learning_rate: 1.0000e-06
# Epoch 360/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1410 - loss: 2.1978 - learning_rate: 1.0000e-06
# Epoch 361/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.1662 - loss: 2.1986 - learning_rate: 1.0000e-06
# Epoch 362/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1706 - loss: 2.1770 - learning_rate: 1.0000e-06
# Epoch 363/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1810 - loss: 2.1853 - learning_rate: 1.0000e-06
# Epoch 364/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1262 - loss: 2.2352 - learning_rate: 1.0000e-06
# Epoch 365/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1706 - loss: 2.1951 - learning_rate: 1.0000e-06
# Epoch 366/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0697 - loss: 2.2155 - learning_rate: 1.0000e-06
# Epoch 367/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1662 - loss: 2.1882 - learning_rate: 1.0000e-06
# Epoch 368/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0757 - loss: 2.1903 - learning_rate: 1.0000e-06
# Epoch 369/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.1262 - loss: 2.1956 - learning_rate: 1.0000e-06
# Epoch 370/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1914 - loss: 2.1674 - learning_rate: 1.0000e-06
# Epoch 371/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.2211 - loss: 2.1769 - learning_rate: 1.0000e-06
# Epoch 372/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1262 - loss: 2.1707 - learning_rate: 1.0000e-06
# Epoch 373/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.1914 - loss: 2.1686 - learning_rate: 1.0000e-06
# Epoch 374/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1009 - loss: 2.1950 - learning_rate: 1.0000e-06
# Epoch 375/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1053 - loss: 2.2032 - learning_rate: 1.0000e-06
# Epoch 376/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1201 - loss: 2.1969 - learning_rate: 1.0000e-06
# Epoch 377/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0801 - loss: 2.2028 - learning_rate: 1.0000e-06
# Epoch 378/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.1410 - loss: 2.1890 - learning_rate: 1.0000e-06
# Epoch 379/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.1009 - loss: 2.1950 - learning_rate: 1.0000e-06
# Epoch 380/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0757 - loss: 2.1802 - learning_rate: 1.0000e-06
# Epoch 381/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0505 - loss: 2.1939 - learning_rate: 1.0000e-06
# Epoch 382/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1810 - loss: 2.1950 - learning_rate: 1.0000e-06
# Epoch 383/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0801 - loss: 2.2048 - learning_rate: 1.0000e-06
# Epoch 384/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0905 - loss: 2.1869 - learning_rate: 1.0000e-06
# Epoch 385/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1009 - loss: 2.1891 - learning_rate: 1.0000e-06
# Epoch 386/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0801 - loss: 2.1997 - learning_rate: 1.0000e-06
# Epoch 387/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1914 - loss: 2.1851 - learning_rate: 1.0000e-06
# ...
# Epoch 862/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.1410 - loss: 2.1894 - learning_rate: 1.0000e-06
# Epoch 863/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1097 - loss: 2.2002 - learning_rate: 1.0000e-06
# Epoch 864/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.1914 - loss: 2.1987 - learning_rate: 1.0000e-06
# Epoch 865/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1306 - loss: 2.2056 - learning_rate: 1.0000e-06
# Epoch 866/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.0444 - loss: 2.2348 - learning_rate: 1.0000e-06
# Epoch 867/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.2019 - loss: 2.1849 - learning_rate: 1.0000e-06
# Epoch 868/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.0949 - loss: 2.2229 - learning_rate: 1.0000e-06
# Epoch 869/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.0549 - loss: 2.1998 - learning_rate: 1.0000e-06
# Epoch 870/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1706 - loss: 2.1810 - learning_rate: 1.0000e-06
# Epoch 871/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2271 - loss: 2.1628 - learning_rate: 1.0000e-06
# Epoch 872/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1662 - loss: 2.1787 - learning_rate: 1.0000e-06
# Epoch 873/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0653 - loss: 2.2058 - learning_rate: 1.0000e-06
# Epoch 874/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1053 - loss: 2.1801 - learning_rate: 1.0000e-06
# Epoch 875/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1958 - loss: 2.1710 - learning_rate: 1.0000e-06
# Epoch 876/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2062 - loss: 2.1719 - learning_rate: 1.0000e-06
# Epoch 877/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1262 - loss: 2.2026 - learning_rate: 1.0000e-06
# Epoch 878/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1053 - loss: 2.2017 - learning_rate: 1.0000e-06
# Epoch 879/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.1306 - loss: 2.1636 - learning_rate: 1.0000e-06
# Epoch 880/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0905 - loss: 2.1994 - learning_rate: 1.0000e-06
# Epoch 881/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1810 - loss: 2.1776 - learning_rate: 1.0000e-06
# Epoch 882/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0549 - loss: 2.1988 - learning_rate: 1.0000e-06
# Epoch 883/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.1306 - loss: 2.1662 - learning_rate: 1.0000e-06
# Epoch 884/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1053 - loss: 2.1778 - learning_rate: 1.0000e-06
# Epoch 885/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1157 - loss: 2.2019 - learning_rate: 1.0000e-06
# Epoch 886/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.0905 - loss: 2.2025 - learning_rate: 1.0000e-06
# Epoch 887/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0905 - loss: 2.2045 - learning_rate: 1.0000e-06
# Epoch 888/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.1201 - loss: 2.1875 - learning_rate: 1.0000e-06
# Epoch 889/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0757 - loss: 2.2244 - learning_rate: 1.0000e-06
# Epoch 890/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1306 - loss: 2.2061 - learning_rate: 1.0000e-06
# Epoch 891/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.1410 - loss: 2.1736 - learning_rate: 1.0000e-06
# Epoch 892/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.1498 - loss: 2.1935 - learning_rate: 1.0000e-06
# Epoch 893/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1009 - loss: 2.2080 - learning_rate: 1.0000e-06
# Epoch 894/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1454 - loss: 2.1758 - learning_rate: 1.0000e-06
# Epoch 895/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0905 - loss: 2.1909 - learning_rate: 1.0000e-06
# Epoch 896/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1262 - loss: 2.1902 - learning_rate: 1.0000e-06
# Epoch 897/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1157 - loss: 2.2105 - learning_rate: 1.0000e-06
# Epoch 898/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1410 - loss: 2.1757 - learning_rate: 1.0000e-06
# Epoch 899/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1706 - loss: 2.1911 - learning_rate: 1.0000e-06
# Epoch 900/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0757 - loss: 2.1919 - learning_rate: 1.0000e-06
# Epoch 901/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0400 - loss: 2.2104 - learning_rate: 1.0000e-06
# Epoch 902/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1854 - loss: 2.1748 - learning_rate: 1.0000e-06
# Epoch 903/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1306 - loss: 2.1951 - learning_rate: 1.0000e-06
# Epoch 904/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1009 - loss: 2.2291 - learning_rate: 1.0000e-06
# Epoch 905/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1097 - loss: 2.1869 - learning_rate: 1.0000e-06
# Epoch 906/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2062 - loss: 2.1585 - learning_rate: 1.0000e-06
# Epoch 907/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1662 - loss: 2.1723 - learning_rate: 1.0000e-06
# Epoch 908/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1306 - loss: 2.1868 - learning_rate: 1.0000e-06
# Epoch 909/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1454 - loss: 2.2085 - learning_rate: 1.0000e-06
# Epoch 910/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1958 - loss: 2.1659 - learning_rate: 1.0000e-06
# Epoch 911/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.0653 - loss: 2.2221 - learning_rate: 1.0000e-06
# Epoch 912/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.1009 - loss: 2.2194 - learning_rate: 1.0000e-06
# Epoch 913/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1053 - loss: 2.2033 - learning_rate: 1.0000e-06
# Epoch 914/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.1454 - loss: 2.2076 - learning_rate: 1.0000e-06
# Epoch 915/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1157 - loss: 2.1850 - learning_rate: 1.0000e-06
# Epoch 916/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1854 - loss: 2.1659 - learning_rate: 1.0000e-06
# Epoch 917/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1201 - loss: 2.1992 - learning_rate: 1.0000e-06
# Epoch 918/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.0949 - loss: 2.2167 - learning_rate: 1.0000e-06
# Epoch 919/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1810 - loss: 2.1929 - learning_rate: 1.0000e-06
# Epoch 920/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0801 - loss: 2.1937 - learning_rate: 1.0000e-06
# Epoch 921/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0949 - loss: 2.1984 - learning_rate: 1.0000e-06
# Epoch 922/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.0801 - loss: 2.1948 - learning_rate: 1.0000e-06
# Epoch 923/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.1306 - loss: 2.2179 - learning_rate: 1.0000e-06
# Epoch 924/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0801 - loss: 2.1947 - learning_rate: 1.0000e-06
# Epoch 925/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1306 - loss: 2.1691 - learning_rate: 1.0000e-06
# Epoch 926/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0400 - loss: 2.2151 - learning_rate: 1.0000e-06
# Epoch 927/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1810 - loss: 2.1735 - learning_rate: 1.0000e-06
# Epoch 928/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0653 - loss: 2.2265 - learning_rate: 1.0000e-06
# Epoch 929/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1097 - loss: 2.2093 - learning_rate: 1.0000e-06
# Epoch 930/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1410 - loss: 2.1641 - learning_rate: 1.0000e-06
# Epoch 931/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1662 - loss: 2.1961 - learning_rate: 1.0000e-06
# Epoch 932/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1810 - loss: 2.1772 - learning_rate: 1.0000e-06
# Epoch 933/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0993 - loss: 2.1994 - learning_rate: 1.0000e-06
# Epoch 934/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1141 - loss: 2.1994 - learning_rate: 1.0000e-06
# Epoch 935/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1201 - loss: 2.2069 - learning_rate: 1.0000e-06
# Epoch 936/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.1854 - loss: 2.2067 - learning_rate: 1.0000e-06
# Epoch 937/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1662 - loss: 2.1835 - learning_rate: 1.0000e-06
# Epoch 938/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1306 - loss: 2.1542 - learning_rate: 1.0000e-06
# Epoch 939/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.1410 - loss: 2.1859 - learning_rate: 1.0000e-06
# Epoch 940/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0801 - loss: 2.2188 - learning_rate: 1.0000e-06
# Epoch 941/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0801 - loss: 2.1890 - learning_rate: 1.0000e-06
# Epoch 942/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3472 - loss: 2.1527 - learning_rate: 1.0000e-06
# Epoch 943/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0801 - loss: 2.2255 - learning_rate: 1.0000e-06
# Epoch 944/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1262 - loss: 2.2176 - learning_rate: 1.0000e-06
# Epoch 945/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0757 - loss: 2.2103 - learning_rate: 1.0000e-06
# Epoch 946/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1306 - loss: 2.1964 - learning_rate: 1.0000e-06
# Epoch 947/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.1306 - loss: 2.2007 - learning_rate: 1.0000e-06
# Epoch 948/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0801 - loss: 2.2268 - learning_rate: 1.0000e-06
# Epoch 949/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1410 - loss: 2.1749 - learning_rate: 1.0000e-06
# Epoch 950/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1097 - loss: 2.1772 - learning_rate: 1.0000e-06
# Epoch 951/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1306 - loss: 2.1844 - learning_rate: 1.0000e-06
# Epoch 952/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1350 - loss: 2.2007 - learning_rate: 1.0000e-06
# Epoch 953/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0505 - loss: 2.2014 - learning_rate: 1.0000e-06
# Epoch 954/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.0905 - loss: 2.2023 - learning_rate: 1.0000e-06
# Epoch 955/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1306 - loss: 2.2086 - learning_rate: 1.0000e-06
# Epoch 956/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.1810 - loss: 2.1499 - learning_rate: 1.0000e-06
# Epoch 957/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1201 - loss: 2.2095 - learning_rate: 1.0000e-06
# Epoch 958/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.2211 - loss: 2.1745 - learning_rate: 1.0000e-06
# Epoch 959/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0905 - loss: 2.1768 - learning_rate: 1.0000e-06
# Epoch 960/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0905 - loss: 2.2097 - learning_rate: 1.0000e-06
# Epoch 961/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1201 - loss: 2.1939 - learning_rate: 1.0000e-06
# Epoch 962/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.1662 - loss: 2.1856 - learning_rate: 1.0000e-06
# Epoch 963/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1410 - loss: 2.1737 - learning_rate: 1.0000e-06
# Epoch 964/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1157 - loss: 2.1908 - learning_rate: 1.0000e-06
# Epoch 965/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1662 - loss: 2.1762 - learning_rate: 1.0000e-06
# Epoch 966/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0801 - loss: 2.2047 - learning_rate: 1.0000e-06
# Epoch 967/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1410 - loss: 2.1982 - learning_rate: 1.0000e-06
# Epoch 968/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0757 - loss: 2.2087 - learning_rate: 1.0000e-06
# Epoch 969/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0905 - loss: 2.1978 - learning_rate: 1.0000e-06
# Epoch 970/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0697 - loss: 2.2192 - learning_rate: 1.0000e-06
# Epoch 971/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1306 - loss: 2.1939 - learning_rate: 1.0000e-06
# Epoch 972/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.1157 - loss: 2.2162 - learning_rate: 1.0000e-06
# Epoch 973/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1009 - loss: 2.2372 - learning_rate: 1.0000e-06
# Epoch 974/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0549 - loss: 2.1968 - learning_rate: 1.0000e-06
# Epoch 975/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.1157 - loss: 2.2012 - learning_rate: 1.0000e-06
# Epoch 976/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1706 - loss: 2.1910 - learning_rate: 1.0000e-06
# Epoch 977/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.1410 - loss: 2.1966 - learning_rate: 1.0000e-06
# Epoch 978/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1454 - loss: 2.2093 - learning_rate: 1.0000e-06
# Epoch 979/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.1201 - loss: 2.2021 - learning_rate: 1.0000e-06
# Epoch 980/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.1558 - loss: 2.1918 - learning_rate: 1.0000e-06
# Epoch 981/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1306 - loss: 2.2033 - learning_rate: 1.0000e-06
# Epoch 982/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.1157 - loss: 2.1876 - learning_rate: 1.0000e-06
# Epoch 983/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1201 - loss: 2.1655 - learning_rate: 1.0000e-06
# Epoch 984/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0653 - loss: 2.1985 - learning_rate: 1.0000e-06
# Epoch 985/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0653 - loss: 2.2093 - learning_rate: 1.0000e-06
# Epoch 986/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0653 - loss: 2.2026 - learning_rate: 1.0000e-06
# Epoch 987/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1514 - loss: 2.1817 - learning_rate: 1.0000e-06
# Epoch 988/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.1306 - loss: 2.1978 - learning_rate: 1.0000e-06
# Epoch 989/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1009 - loss: 2.1653 - learning_rate: 1.0000e-06
# Epoch 990/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1454 - loss: 2.1976 - learning_rate: 1.0000e-06
# Epoch 991/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0845 - loss: 2.1999 - learning_rate: 1.0000e-06
# Epoch 992/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1306 - loss: 2.1611 - learning_rate: 1.0000e-06
# Epoch 993/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 277us/step - accuracy: 0.2567 - loss: 2.1423 - learning_rate: 1.0000e-06
# Epoch 994/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1053 - loss: 2.2070 - learning_rate: 1.0000e-06
# Epoch 995/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.0653 - loss: 2.2034 - learning_rate: 1.0000e-06
# Epoch 996/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2819 - loss: 2.1392 - learning_rate: 1.0000e-06
# Epoch 997/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1306 - loss: 2.1797 - learning_rate: 1.0000e-06
# Epoch 998/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0653 - loss: 2.1857 - learning_rate: 1.0000e-06
# Epoch 999/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1157 - loss: 2.1835 - learning_rate: 1.0000e-06
# Epoch 1000/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0757 - loss: 2.2244 - learning_rate: 1.0000e-06

# %%
model_path = PIPELINE_CONFIG["save_paths"]["model"]
model.save(model_path)
print(f"Trained model saved to {model_path}")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Trained model saved to trained_model.h5
